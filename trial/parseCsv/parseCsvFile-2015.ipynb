# %%
from __future__ import division
from numpy.random import randn
from pandas import Series
import numpy as np
import pandas as pd
np.set_printoptions(precision=4)
import sys; sys.path.append('book_scripts')
# %cd book_scripts
# Out:
# [Error 2] : u'book_scripts'
# E:\project\pychram\book_scripts

# %%
# input CSV数据文件
input_stock_data_path = 'E:/project/pychram/traderesp/strategy/input-csv/'
input_stock_data_cvs = input_stock_data_path + 'input-stock-2015.csv'

# %%
# 注意：这里请填写数据文件在您电脑中的路径，并注意路径中斜杠的方向
stock_data = pd.read_csv(input_stock_data_cvs,encoding='gbk')

# %%
stock_data.fillna('miss')
# Out:
#     2015/2/3        代码     名称   MLX Unnamed: 4 2015/2/4      代码.1   名称.1  \
# 0          1  '600107'    美尔雅    36       miss        1  '600491'   龙元建设
# 1          2  '002538'  司尔特      32       miss        2  '601139'   深圳燃气
# 2          3  '002024'   苏宁云商    32       miss        3  '600021'   上海电力
# 3          4  '002237'   恒邦股份    30       miss        4  '002084'   海鸥卫浴
# 4          5  '601633'   长城汽车    30       miss        5  '002184'   海得控制
# 5          6  '600895'   张江高科    30       miss        6  '601877'   正泰电器
# 6          7  '600588'   用友网络    26       miss        7  '002239'  金 飞 达
# 7          8  '002033'   丽江旅游    11       miss        8  '601888'   中国国旅
# 8          9  '000625'   长安汽车    10       miss        9  '002344'   海宁皮城
# 9         10  '600998'    九州通     9       miss       10  '600149'   廊坊发展
# 10        11  '600326'   西藏天路     9       miss       11  '002268'  卫 士 通
# 11        12  '000703'   恒逸石化     8       miss       12  '000619'   海螺型材
# 12        13  '002210'   飞马国际     5       miss       13  '002310'   东方园林
# 13        14  '002191'   劲嘉股份     5       miss       14  '002103'   广博股份
# 14        15  '000550'   江铃汽车     5       miss       15  '002373'   千方科技
# 15        16  '601012'   隆基股份     5       miss       16  '601216'   内蒙君正
# 16        17  '002701'  奥瑞金       4       miss       17  '000530'   大冷股份
# 17        18  '002657'   中科金财     4       miss       18  '002250'   联化科技
# 18        19  '002493'   荣盛石化     4       miss       19  '002081'  金 螳 螂
# 19        20  '002400'   省广股份     4       miss       20  '002349'   精华制药
# 20        21  '002285'  世联行       4       miss       21  '600433'   冠豪高新
# 21        22  '002095'  生 意 宝     4       miss       22  '002315'   焦点科技
# 22        23  '000921'   海信科龙     4       miss       23  '002223'   鱼跃医疗
# 23        24  '600599'   熊猫烟花     4       miss       24  '000797'   中国武夷
# 24        25  '600180'    瑞茂通     4       miss       25  '000048'  康达尔
# 25        26  '002616'   长青集团     3       miss       26  '600459'   贵研铂业
# 26        27  '002436'   兴森科技     3       miss       27  '600038'   中直股份
# 27        28  '001896'   豫能控股     3       miss       28  '002712'   思美传媒
# 28        29  '000820'   金城股份     3       miss       29  '002711'   欧浦钢网
# 29        30  '000793'   华闻传媒     3       miss       30  '002485'  希努尔
# ..       ...       ...    ...   ...        ...      ...       ...    ...
# 398     miss      miss   miss  miss       miss     miss      miss   miss
# 399     miss      miss   miss  miss       miss     miss      miss   miss
# 400     miss      miss   miss  miss       miss     miss      miss   miss
# 401     miss      miss   miss  miss       miss     miss      miss   miss
# 402     miss      miss   miss  miss       miss     miss      miss   miss
# 403     miss      miss   miss  miss       miss     miss      miss   miss
# 404     miss      miss   miss  miss       miss     miss      miss   miss
# 405     miss      miss   miss  miss       miss     miss      miss   miss
# 406     miss      miss   miss  miss       miss     miss      miss   miss
# 407     miss      miss   miss  miss       miss     miss      miss   miss
# 408     miss      miss   miss  miss       miss     miss      miss   miss
# 409     miss      miss   miss  miss       miss     miss      miss   miss
# 410     miss      miss   miss  miss       miss     miss      miss   miss
# 411     miss      miss   miss  miss       miss     miss      miss   miss
# 412     miss      miss   miss  miss       miss     miss      miss   miss
# 413     miss      miss   miss  miss       miss     miss      miss   miss
# 414     miss      miss   miss  miss       miss     miss      miss   miss
# 415     miss      miss   miss  miss       miss     miss      miss   miss
# 416     miss      miss   miss  miss       miss     miss      miss   miss
# 417     miss      miss   miss  miss       miss     miss      miss   miss
# 418     miss      miss   miss  miss       miss     miss      miss   miss
# 419     miss      miss   miss  miss       miss     miss      miss   miss
# 420     miss      miss   miss  miss       miss     miss      miss   miss
# 421     miss      miss   miss  miss       miss     miss      miss   miss
# 422     miss      miss   miss  miss       miss     miss      miss   miss
# 423     miss      miss   miss  miss       miss     miss      miss   miss
# 424     miss      miss   miss  miss       miss     miss      miss   miss
# 425     miss      miss   miss  miss       miss     miss      miss   miss
# 426     miss      miss   miss  miss       miss     miss      miss   miss
# 427     miss      miss   miss  miss       miss     miss      miss   miss
#
#     MLX.1 Unnamed: 9   ...    Unnamed: 734 2015/11/5    代码.147 名称.147  \
# 0      51       miss   ...            miss         1  '002213'  特 尔 佳
# 1      46       miss   ...            miss         2  '600980'   北矿磁材
# 2      30       miss   ...            miss         3  '002723'  金莱特
# 3      24       miss   ...            miss         4  '002494'   华斯股份
# 4      18       miss   ...            miss         5  '002425'   凯撒股份
# 5      14       miss   ...            miss         6  '002188'  新 嘉 联
# 6      12       miss   ...            miss         7  '600523'   贵航股份
# 7      12       miss   ...            miss         8  '600279'   重庆港九
# 8      11       miss   ...            miss         9  '002560'   通达股份
# 9      11       miss   ...            miss        10  '601599'   鹿港科技
# 10     10       miss   ...            miss        11  '000430'  张家界
# 11     10       miss   ...            miss        12  '002290'   禾盛新材
# 12      9       miss   ...            miss        13  '601800'   中国交建
# 13      9       miss   ...            miss        14  '000422'   湖北宜化
# 14      8       miss   ...            miss        15  '002419'   天虹商场
# 15      6       miss   ...            miss        16  '002437'   誉衡药业
# 16      5       miss   ...            miss        17  '000802'   北京文化
# 17      4       miss   ...            miss        18  '002630'   华西能源
# 18      4       miss   ...            miss        19  '002518'  科士达
# 19      3       miss   ...            miss        20  '000011'  深物业A
# 20      3       miss   ...            miss        21  '000687'   华讯方舟
# 21      2       miss   ...            miss        22  '600894'   广日股份
# 22      2       miss   ...            miss        23  '600479'   千金药业
# 23      2       miss   ...            miss        24  '600973'   宝胜股份
# 24      2       miss   ...            miss        25  '600787'   中储股份
# 25      2       miss   ...            miss        26  '002573'   清新环境
# 26      2       miss   ...            miss        27  '600093'   禾嘉股份
# 27      1       miss   ...            miss        28  '601009'   南京银行
# 28      1       miss   ...            miss        29  '600223'   鲁商置业
# 29      1       miss   ...            miss        30  '600415'   小商品城
# ..    ...        ...   ...             ...       ...       ...    ...
# 398  miss       miss   ...            miss      miss      miss   miss
# 399  miss       miss   ...            miss      miss      miss   miss
# 400  miss       miss   ...            miss      miss      miss   miss
# 401  miss       miss   ...            miss      miss      miss   miss
# 402  miss       miss   ...            miss      miss      miss   miss
# 403  miss       miss   ...            miss      miss      miss   miss
# 404  miss       miss   ...            miss      miss      miss   miss
# 405  miss       miss   ...            miss      miss      miss   miss
# 406  miss       miss   ...            miss      miss      miss   miss
# 407  miss       miss   ...            miss      miss      miss   miss
# 408  miss       miss   ...            miss      miss      miss   miss
# 409  miss       miss   ...            miss      miss      miss   miss
# 410  miss       miss   ...            miss      miss      miss   miss
# 411  miss       miss   ...            miss      miss      miss   miss
# 412  miss       miss   ...            miss      miss      miss   miss
# 413  miss       miss   ...            miss      miss      miss   miss
# 414  miss       miss   ...            miss      miss      miss   miss
# 415  miss       miss   ...            miss      miss      miss   miss
# 416  miss       miss   ...            miss      miss      miss   miss
# 417  miss       miss   ...            miss      miss      miss   miss
# 418  miss       miss   ...            miss      miss      miss   miss
# 419  miss       miss   ...            miss      miss      miss   miss
# 420  miss       miss   ...            miss      miss      miss   miss
# 421  miss       miss   ...            miss      miss      miss   miss
# 422  miss       miss   ...            miss      miss      miss   miss
# 423  miss       miss   ...            miss      miss      miss   miss
# 424  miss       miss   ...            miss      miss      miss   miss
# 425  miss       miss   ...            miss      miss      miss   miss
# 426  miss       miss   ...            miss      miss      miss   miss
# 427  miss       miss   ...            miss      miss      miss   miss
#
#     KDJJ值.85 Unnamed: 739 2015/11/9    代码.148 名称.148 KDJJ值.86
# 0         91         miss         1  '002676'   顺威股份       93
# 1         89         miss         2  '603010'   万盛股份       91
# 2         89         miss         3  '600520'   中发科技       91
# 3         87         miss         4  '002278'   神开股份       90
# 4         86         miss         5  '000722'   湖南发展       90
# 5         85         miss         6  '002123'   荣信股份       89
# 6         84         miss         7  '002010'   传化股份       88
# 7         84         miss         8  '002329'   皇氏集团       87
# 8         82         miss         9  '002074'   国轩高科       87
# 9         82         miss        10  '002508'   老板电器       87
# 10        81         miss        11  '002513'   蓝丰生化       85
# 11        81         miss        12  '002402'  和而泰         85
# 12        80         miss        13  '600330'   天通股份       84
# 13        80         miss        14  '002261'   拓维信息       83
# 14        79         miss        15  '000555'   神州信息       83
# 15        78         miss        16  '002643'   万润股份       82
# 16        78         miss        17  '002583'  海能达         82
# 17        77         miss        18  '600463'   空港股份       81
# 18        76         miss        19  '002725'   跃岭股份       80
# 19        75         miss        20  '002135'   东南网架       80
# 20        75         miss        21  '002584'   西陇化工       80
# 21        75         miss        22  '002587'   奥拓电子       79
# 22        74         miss        23  '002407'  多氟多         78
# 23        74         miss        24  '002551'   尚荣医疗       78
# 24        73         miss        25  '600865'   百大集团       78
# 25        73         miss        26  '002380'   科远股份       78
# 26        72         miss        27  '002101'   广东鸿图       77
# 27        72         miss        28  '002594'  比亚迪         77
# 28        72         miss        29  '600673'   东阳光科       77
# 29        71         miss        30  '002658'  雪迪龙         76
# ..       ...          ...       ...       ...    ...      ...
# 398     miss         miss      miss      miss   miss     miss
# 399     miss         miss      miss      miss   miss     miss
# 400     miss         miss      miss      miss   miss     miss
# 401     miss         miss      miss      miss   miss     miss
# 402     miss         miss      miss      miss   miss     miss
# 403     miss         miss      miss      miss   miss     miss
# 404     miss         miss      miss      miss   miss     miss
# 405     miss         miss      miss      miss   miss     miss
# 406     miss         miss      miss      miss   miss     miss
# 407     miss         miss      miss      miss   miss     miss
# 408     miss         miss      miss      miss   miss     miss
# 409     miss         miss      miss      miss   miss     miss
# 410     miss         miss      miss      miss   miss     miss
# 411     miss         miss      miss      miss   miss     miss
# 412     miss         miss      miss      miss   miss     miss
# 413     miss         miss      miss      miss   miss     miss
# 414     miss         miss      miss      miss   miss     miss
# 415     miss         miss      miss      miss   miss     miss
# 416     miss         miss      miss      miss   miss     miss
# 417     miss         miss      miss      miss   miss     miss
# 418     miss         miss      miss      miss   miss     miss
# 419     miss         miss      miss      miss   miss     miss
# 420     miss         miss      miss      miss   miss     miss
# 421     miss         miss      miss      miss   miss     miss
# 422     miss         miss      miss      miss   miss     miss
# 423     miss         miss      miss      miss   miss     miss
# 424     miss         miss      miss      miss   miss     miss
# 425     miss         miss      miss      miss   miss     miss
# 426     miss         miss      miss      miss   miss     miss
# 427     miss         miss      miss      miss   miss     miss
#
# [428 rows x 744 columns]

# %%
stock_data.columns
# Out:
# Index([    u'2015/2/3',           u'代码',           u'名称',          u'MLX',
#          u'Unnamed: 4',     u'2015/2/4',         u'代码.1',         u'名称.1',
#               u'MLX.1',   u'Unnamed: 9',
#        ...
#        u'Unnamed: 734',    u'2015/11/5',       u'代码.147',       u'名称.147',
#            u'KDJJ值.85', u'Unnamed: 739',    u'2015/11/9',       u'代码.148',
#              u'名称.148',     u'KDJJ值.86'],
#       dtype='object', length=744)

# %%
stock_data.columns[0]
# Out:
# u'2015/2/3'

# %%
stock_data.columns[4]
# Out:
# 'Unnamed: 4'

# %%
stock_data.iloc[0][1]
# Out:
# u"'600107'"

# %%
stock_data.iloc[0][2]
# Out:
# u'\u7f8e\u5c14\u96c5'

# %%
print stock_data.iloc[0][2]
# Out:
# 美尔雅

# %%
len(stock_data.columns)
# Out:
# 744

# %%
col_num = len(stock_data.columns)

# %%
#first function ,spend time lots
all_stock = pd.DataFrame()
i=0
while i <= col_num : 
    date=stock_data.columns[i]
    code=stock_data.columns[i + 1]
    code_cn=stock_data.columns[i + 2]
    print date,code,code_cn
    #
    for idx, row in stock_data.iterrows():
        # 选取需要的字段，去除其他不需要的字段
        if len(str(row[code])) > 4 :
            stock_record = pd.Series([date,row[code],row[code_cn]])
            all_stock = all_stock.append(stock_record, ignore_index=True)
    #    
    i+=5
# Out:
# 2015/2/3 代码 名称
# 2015/2/4 代码.1 名称.1
# 2015/2/5 代码.2 名称.2
# 2015/2/6 代码.3 名称.3
# 2015/2/9 代码.4 名称.4
# 2015/2/10 代码.5 名称.5
# 2015/2/11 代码.6 名称.6
# 2015/2/12 代码.7 名称.7
# 2015/2/13 代码.8 名称.8
# 2015/2/16 代码.9 名称.9
# 2015/2/17 代码.10 名称.10
# 2015/2/25 代码.11 名称.11
# 2015/2/26 代码.12 名称.12
# 2015/2/27 代码.13 名称.13
# 2015/3/2 代码.14 名称.14
# 2015/3/3 代码.15 名称.15
# 2015/3/4 代码.16 名称.16
# 2015/3/5 代码.17 名称.17
# 2015/3/6 代码.18 名称.18
# 2015/3/9 代码.19 名称.19
# 2015/3/10 代码.20 名称.20
# 2015/3/11 代码.21 名称.21
# 2015/3/12 代码.22 名称.22
# 2015/3/16 代码.23 名称.23
# 2015/3/17 代码.24 名称.24
# 2015/3/18 代码.25 名称.25
# 2015/3/19 代码.26 名称.26
# 2015/3/20 代码.27 名称.27
# 2015/3/23 代码.28 名称.28
# 2015/3/24 代码.29 名称.29
# 2015/3/25 代码.30 名称.30
# 2015/3/26 代码.31 名称.31
# 2015/3/27 代码.32 名称.32
# 2015/3/30 代码.33 名称.33
# 2015/3/31 代码.34 名称.34
# 2015/4/1 代码.35 名称.35
# 2015/4/2 代码.36 名称.36
# 2015/4/3 代码.37 名称.37
# 2015/4/7 代码.38 名称.38
# 2015/4/8 代码.39 名称.39
# 2015/4/9 代码.40 名称.40
# 2015/4/10 代码.41 名称.41
# 2015/4/13 代码.42 名称.42
# 2015/4/14 代码.43 名称.43
# 2015/4/15 代码.44 名称.44
# 2015/4/16 代码.45 名称.45
# 2015/4/17 代码.46 名称.46
# 2015/4/20 代码.47 名称.47
# 2015/4/21 代码.48 名称.48
# 2015/4/22 代码.49 名称.49
# 2015/4/23 代码.50 名称.50
# 2015/4/24 代码.51 名称.51
# 2015/4/27 代码.52 名称.52
# 2015/4/28 代码.53 名称.53
# 2015/4/29 代码.54 名称.54
# 2015/4/30 代码.55 名称.55
# 2015/5/4 代码.56 名称.56
# 2015/5/5 代码.57 名称.57
# 2015/5/6 代码.58 名称.58
# 2015/5/7 代码.59 名称.59
# 2015/5/8 代码.60 名称.60
# 2015/5/11 代码.61 名称.61
# 2015/5/12 代码.62 名称.62
# 2015/5/13 代码.63 名称.63
# 2015/5/14 代码.64 名称.64
# 2015/5/15 代码.65 名称.65
# 2015/5/18 代码.66 名称.66
# 2015/5/19 代码.67 名称.67
# 2015/5/20 代码.68 名称.68
# 2015/5/21 代码.69 名称.69
# 2015/5/22 代码.70 名称.70
# 2015/5/25 代码.71 名称.71
# 2015/5/26 代码.72 名称.72
# 2015/5/27 代码.73 名称.73
# 2015/5/28 代码.74 名称.74
# 2015/5/29 代码.75 名称.75
# 2015/6/1 代码.76 名称.76
# 2015/6/2 代码.77 名称.77
# 2015/6/3 代码.78 名称.78
# 2015/6/4 代码.79 名称.79
# 2015/6/5 代码.80 名称.80
# 2015/6/8 代码.81 名称.81
# 2015/6/9 代码.82 名称.82
# 2015/6/10 代码.83 名称.83
# 2015/6/11 代码.84 名称.84
# 2015/6/12 代码.85 名称.85
# 2015/6/15 代码.86 名称.86
# 2015/6/16 代码.87 名称.87
# 2015/6/17 代码.88 名称.88
# 2015/6/18 代码.89 名称.89
# 2015/6/19 代码.90 名称.90
# 2015/6/23 代码.91 名称.91
# 2015/6/24 代码.92 名称.92
# 2015/6/25 代码.93 名称.93
# 2015/6/29 代码.94 名称.94
# 2015/6/30 代码.95 名称.95
# 2015/7/1 代码.96 名称.96
# 2015/7/10 代码.97 名称.97
# 2015/7/13 代码.98 名称.98
# 2015/7/14 代码.99 名称.99
# 2015/7/17 代码.100 名称.100
# 2015/7/21 代码.101 名称.101
# 2015/7/22 代码.102 名称.102
# 2015/7/23 代码.103 名称.103
# 2015/7/24 代码.104 名称.104
# 2015/7/28 代码.105 名称.105
# 2015/7/29 代码.106 名称.106
# 2015/7/31 代码.107 名称.107
# 2015/8/4 代码.108 名称.108
# 2015/8/6 代码.109 名称.109
# 2015/8/7 代码.110 名称.110
# 2015/8/10 代码.111 名称.111
# 2015/8/11 代码.112 名称.112
# 2015/8/12 代码.113 名称.113
# 2015/8/14 代码.114 名称.114
# 2015/8/17 代码.115 名称.115
# 2015/8/19 代码.116 名称.116
# 2015/8/20 代码.117 名称.117
# 2015/8/27 代码.118 名称.118
# 2015/8/31 代码.119 名称.119
# 2015/9/10 代码.120 名称.120
# 2015/9/11 代码.121 名称.121
# 2015/9/16 代码.122 名称.122
# 2015/9/21 代码.123 名称.123
# 2015/9/22 代码.124 名称.124
# 2015/9/25 代码.125 名称.125
# 2015/9/28 代码.126 名称.126
# 2015/10/8 代码.127 名称.127
# 2015/10/9 代码.128 名称.128
# 2015/10/12 代码.129 名称.129
# 2015/10/13 代码.130 名称.130
# 2015/10/14 代码.131 名称.131
# 2015/10/15 代码.132 名称.132
# 2015/10/16 代码.133 名称.133
# 2015/10/19 代码.134 名称.134
# 2015/10/20 代码.135 名称.135
# 2015/10/21 代码.136 名称.136
# 2015/10/22 代码.137 名称.137
# 2015/10/23 代码.138 名称.138
# 2015/10/26 代码.139 名称.139
# 2015/10/27 代码.140 名称.140
# 2015/10/28 代码.141 名称.141
# 2015/10/29 代码.142 名称.142
# 2015/10/30 代码.143 名称.143
# 2015/11/2 代码.144 名称.144
# 2015/11/3 代码.145 名称.145
# 2015/11/4 代码.146 名称.146
# 2015/11/5 代码.147 名称.147
# 2015/11/9 代码.148 名称.148

# %%
#second function,spends times low
all_stock = pd.DataFrame()
for idx, row in stock_data.iterrows():
    i=0
    while i <= col_num : 
        date=stock_data.columns[i]
        code=stock_data.columns[i + 1]
        code_cn=stock_data.columns[i + 2]
        #print date,code,code_cn
        # 选取需要的字段，去除其他不需要的字段
        if len(str(row[code])) > 4 :
            stock_record = pd.Series([date,row[code],row[code_cn]])
            all_stock = all_stock.append(stock_record, ignore_index=True)
        i+=5

# %%
all_stock
# Out:
#               0         1       2
# 0      2015/2/3  '600107'     美尔雅
# 1      2015/2/3  '002538'   司尔特
# 2      2015/2/3  '002024'    苏宁云商
# 3      2015/2/3  '002237'    恒邦股份
# 4      2015/2/3  '601633'    长城汽车
# 5      2015/2/3  '600895'    张江高科
# 6      2015/2/3  '600588'    用友网络
# 7      2015/2/3  '002033'    丽江旅游
# 8      2015/2/3  '000625'    长安汽车
# 9      2015/2/3  '600998'     九州通
# 10     2015/2/3  '600326'    西藏天路
# 11     2015/2/3  '000703'    恒逸石化
# 12     2015/2/3  '002210'    飞马国际
# 13     2015/2/3  '002191'    劲嘉股份
# 14     2015/2/3  '000550'    江铃汽车
# 15     2015/2/3  '601012'    隆基股份
# 16     2015/2/3  '002701'   奥瑞金
# 17     2015/2/3  '002657'    中科金财
# 18     2015/2/3  '002493'    荣盛石化
# 19     2015/2/3  '002400'    省广股份
# 20     2015/2/3  '002285'   世联行
# 21     2015/2/3  '002095'   生 意 宝
# 22     2015/2/3  '000921'    海信科龙
# 23     2015/2/3  '600599'    熊猫烟花
# 24     2015/2/3  '600180'     瑞茂通
# 25     2015/2/3  '002616'    长青集团
# 26     2015/2/3  '002436'    兴森科技
# 27     2015/2/3  '001896'    豫能控股
# 28     2015/2/3  '000820'    金城股份
# 29     2015/2/3  '000793'    华闻传媒
# ...         ...       ...     ...
# 9420  2015/11/9  '000009'    中国宝安
# 9421  2015/11/9  '600055'    华润万东
# 9422  2015/11/9  '600343'    航天动力
# 9423  2015/11/9  '002059'    云南旅游
# 9424  2015/11/9  '002316'    键桥通讯
# 9425  2015/11/9  '002023'    海特高新
# 9426  2015/11/9  '600038'    中直股份
# 9427  2015/11/9  '600917'    重庆燃气
# 9428  2015/11/9  '002172'    澳洋科技
# 9429  2015/11/9  '000018'  中冠A
# 9430  2015/11/9  '600278'    东方创业
# 9431  2015/11/9  '002666'    德联集团
# 9432  2015/11/9  '000990'    诚志股份
# 9433  2015/11/9  '601886'    江河创建
# 9434  2015/11/9  '000919'    金陵药业
# 9435  2015/11/9  '002246'    北化股份
# 9436  2015/11/9  '002442'    龙星化工
# 9437  2015/11/9  '000559'    万向钱潮
# 9438  2015/11/9  '600220'    江苏阳光
# 9439  2015/11/9  '000797'    中国武夷
# 9440  2015/11/9  '600190'     锦州港
# 9441  2015/11/9  '000005'    世纪星源
# 9442  2015/11/9  '002227'   奥 特 迅
# 9443  2015/11/9  '002429'    兆驰股份
# 9444  2015/11/9  '600399'    抚顺特钢
# 9445  2015/11/9  '002093'    国脉科技
# 9446  2015/11/9  '000698'    沈阳化工
# 9447  2015/11/9  '002231'    奥维通信
# 9448  2015/11/9  '002703'    浙江世宝
# 9449  2015/11/9  '002427'    尤夫股份
#
# [9450 rows x 3 columns]

# %%
# 添加列名称
all_stock.columns=['date','code','code_cn']

# %%
all_stock.index.name='id'

# %%
# ========== 将算好的数据输出到csv文件 - 注意：这里请填写输出文件在您电脑中的路径
# output CSV数据文件
output_stock_data_path = 'E:/project/pychram/traderesp/strategy/output-csv/'
output_stock_data_cvs = output_stock_data_path + 'output-stock-2015.csv'
all_stock.to_csv(output_stock_data_cvs,encoding='gbk', index=False)
