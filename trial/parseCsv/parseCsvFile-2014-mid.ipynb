# %%
from __future__ import division
from numpy.random import randn
from pandas import Series
import numpy as np
import pandas as pd
np.set_printoptions(precision=4)
import sys; sys.path.append('book_scripts')
# %pwd book_scripts
# Out:
# u'E:\\project\\pychram\\book_scripts'

# %%
# input CSV数据文件
input_stock_data_path = 'E:/project/pychram/traderesp/strategy/input-csv/'
input_stock_data_cvs = input_stock_data_path + 'input-stock-2014-mid.csv'
# output CSV数据文件
output_stock_data_path = 'E:/project/pychram/traderesp/strategy/output-csv/'
output_stock_data_cvs = output_stock_data_path + 'output-stock-2014-mid.csv'

# %%
# 注意：这里请填写数据文件在您电脑中的路径，并注意路径中斜杠的方向
stock_data = pd.read_csv(input_stock_data_cvs,encoding='gbk')

# %%
stock_data.fillna('miss')
# Out:
#     2014/6/4        代码     名称 MIDSZ Unnamed: 4 2014/6/5      代码.1   名称.1  \
# 0          1  '002626'  金达威      93       miss        1  '002626'  金达威
# 1          2  '600432'   吉恩镍业    58       miss        2  '002228'   合兴包装
# 2          3  '600317'    营口港    45       miss        3  '600432'   吉恩镍业
# 3          4  '002404'   嘉欣丝绸    42       miss        4  '600317'    营口港
# 4          5  '000998'   隆平高科    39       miss        5  '002404'   嘉欣丝绸
# 5          6  '000761'   本钢板材    37       miss        6  '000998'   隆平高科
# 6          7  '002345'  潮宏基      36       miss        7  '000761'   本钢板材
# 7          8  '002235'   安妮股份    36       miss        8  '002345'  潮宏基
# 8          9  '002030'   达安基因    36       miss        9  '002235'   安妮股份
# 9         10  '000413'   东旭光电    33       miss       10  '002030'   达安基因
# 10        11  '002514'   宝馨科技    32       miss       11  '000413'   东旭光电
# 11        12  '002099'   海翔药业    32       miss       12  '600279'   重庆港九
# 12        13  '002215'  诺 普 信    31       miss       13  '002514'   宝馨科技
# 13        14  '002715'   登云股份    30       miss       14  '002099'   海翔药业
# 14        15  '002662'   京威股份    30       miss       15  '002215'  诺 普 信
# 15        16  '002364'   中恒电气    30       miss       16  '002715'   登云股份
# 16        17  '002427'   尤夫股份    25       miss       17  '002364'   中恒电气
# 17        18  '601007'   金陵饭店    25       miss       18  '002388'   新亚制程
# 18        19  '600876'   洛阳玻璃    25       miss       19  '002427'   尤夫股份
# 19        20  '002700'   新疆浩源    24       miss       20  '601007'   金陵饭店
# 20        21  '600562'   国睿科技    24       miss       21  '600876'   洛阳玻璃
# 21        22  '600081'   东风科技    24       miss       22  '002700'   新疆浩源
# 22        23  '002627'   宜昌交运    23       miss       23  '002615'  哈尔斯
# 23        24  '002026'   山东威达    23       miss       24  '600854'   春兰股份
# 24        25  '000055'   方大集团    23       miss       25  '600562'   国睿科技
# 25        26  '601001'   大同煤业    23       miss       26  '600081'   东风科技
# 26        27  '600857'   工大首创    23       miss       27  '002627'   宜昌交运
# 27        28  '600351'   亚宝药业    23       miss       28  '002026'   山东威达
# 28        29  '002453'   天马精化    22       miss       29  '000055'   方大集团
# 29        30  '002194'   武汉凡谷    22       miss       30  '601001'   大同煤业
# ..       ...       ...    ...   ...        ...      ...       ...    ...
# 504     miss      miss   miss  miss       miss     miss      miss   miss
# 505     miss      miss   miss  miss       miss     miss      miss   miss
# 506     miss      miss   miss  miss       miss     miss      miss   miss
# 507     miss      miss   miss  miss       miss     miss      miss   miss
# 508     miss      miss   miss  miss       miss     miss      miss   miss
# 509     miss      miss   miss  miss       miss     miss      miss   miss
# 510     miss      miss   miss  miss       miss     miss      miss   miss
# 511     miss      miss   miss  miss       miss     miss      miss   miss
# 512     miss      miss   miss  miss       miss     miss      miss   miss
# 513     miss      miss   miss  miss       miss     miss      miss   miss
# 514     miss      miss   miss  miss       miss     miss      miss   miss
# 515     miss      miss   miss  miss       miss     miss      miss   miss
# 516     miss      miss   miss  miss       miss     miss      miss   miss
# 517     miss      miss   miss  miss       miss     miss      miss   miss
# 518     miss      miss   miss  miss       miss     miss      miss   miss
# 519     miss      miss   miss  miss       miss     miss      miss   miss
# 520     miss      miss   miss  miss       miss     miss      miss   miss
# 521     miss      miss   miss  miss       miss     miss      miss   miss
# 522     miss      miss   miss  miss       miss     miss      miss   miss
# 523     miss      miss   miss  miss       miss     miss      miss   miss
# 524     miss      miss   miss  miss       miss     miss      miss   miss
# 525     miss      miss   miss  miss       miss     miss      miss   miss
# 526     miss      miss   miss  miss       miss     miss      miss   miss
# 527     miss      miss   miss  miss       miss     miss      miss   miss
# 528     miss      miss   miss  miss       miss     miss      miss   miss
# 529     miss      miss   miss  miss       miss     miss      miss   miss
# 530     miss      miss   miss  miss       miss     miss      miss   miss
# 531     miss      miss   miss  miss       miss     miss      miss   miss
# 532     miss      miss   miss  miss       miss     miss      miss   miss
# 533     miss      miss   miss  miss       miss     miss      miss   miss
#
#     MIDSZ.1 Unnamed: 9   ...    Unnamed: 504 2014/10/31    代码.101 名称.101  \
# 0        94       miss   ...            miss          1  '000534'   万泽股份
# 1        88       miss   ...            miss          2  '002272'   川润股份
# 2        59       miss   ...            miss          3  '002107'   沃华医药
# 3        46       miss   ...            miss          4  '000566'   海南海药
# 4        43       miss   ...            miss          5  '002401'   中海科技
# 5        40       miss   ...            miss          6  '002205'   国统股份
# 6        38       miss   ...            miss          7  '002544'   杰赛科技
# 7        37       miss   ...            miss          8  '002068'   黑猫股份
# 8        37       miss   ...            miss          9  '002338'   奥普光电
# 9        37       miss   ...            miss         10  '600674'   川投能源
# 10       34       miss   ...            miss         11  '000567'   海德股份
# 11       34       miss   ...            miss         12  '600356'   恒丰纸业
# 12       33       miss   ...            miss         13  '002171'   精诚铜业
# 13       33       miss   ...            miss         14  '002105'   信隆实业
# 14       32       miss   ...            miss         15  '002268'  卫 士 通
# 15       31       miss   ...            miss         16  '002616'   长青集团
# 16       31       miss   ...            miss         17  '002670'   华声股份
# 17       28       miss   ...            miss         18  '002318'   久立特材
# 18       26       miss   ...            miss         19  '002222'   福晶科技
# 19       26       miss   ...            miss         20  '002441'  众业达
# 20       26       miss   ...            miss         21  '002169'   智光电气
# 21       25       miss   ...            miss         22  '600038'   哈飞股份
# 22       25       miss   ...            miss         23  '002193'   山东如意
# 23       25       miss   ...            miss         24  '600976'   武汉健民
# 24       25       miss   ...            miss         25  '000099'   中信海直
# 25       25       miss   ...            miss         26  '600558'    大西洋
# 26       24       miss   ...            miss         27  '002089'  新 海 宜
# 27       24       miss   ...            miss         28  '002621'   大连三垒
# 28       24       miss   ...            miss         29  '002593'   日上集团
# 29       24       miss   ...            miss         30  '002189'   利达光电
# ..      ...        ...   ...             ...        ...       ...    ...
# 504    miss       miss   ...            miss       miss      miss   miss
# 505    miss       miss   ...            miss       miss      miss   miss
# 506    miss       miss   ...            miss       miss      miss   miss
# 507    miss       miss   ...            miss       miss      miss   miss
# 508    miss       miss   ...            miss       miss      miss   miss
# 509    miss       miss   ...            miss       miss      miss   miss
# 510    miss       miss   ...            miss       miss      miss   miss
# 511    miss       miss   ...            miss       miss      miss   miss
# 512    miss       miss   ...            miss       miss      miss   miss
# 513    miss       miss   ...            miss       miss      miss   miss
# 514    miss       miss   ...            miss       miss      miss   miss
# 515    miss       miss   ...            miss       miss      miss   miss
# 516    miss       miss   ...            miss       miss      miss   miss
# 517    miss       miss   ...            miss       miss      miss   miss
# 518    miss       miss   ...            miss       miss      miss   miss
# 519    miss       miss   ...            miss       miss      miss   miss
# 520    miss       miss   ...            miss       miss      miss   miss
# 521    miss       miss   ...            miss       miss      miss   miss
# 522    miss       miss   ...            miss       miss      miss   miss
# 523    miss       miss   ...            miss       miss      miss   miss
# 524    miss       miss   ...            miss       miss      miss   miss
# 525    miss       miss   ...            miss       miss      miss   miss
# 526    miss       miss   ...            miss       miss      miss   miss
# 527    miss       miss   ...            miss       miss      miss   miss
# 528    miss       miss   ...            miss       miss      miss   miss
# 529    miss       miss   ...            miss       miss      miss   miss
# 530    miss       miss   ...            miss       miss      miss   miss
# 531    miss       miss   ...            miss       miss      miss   miss
# 532    miss       miss   ...            miss       miss      miss   miss
# 533    miss       miss   ...            miss       miss      miss   miss
#
#     MIDSZ.82 Unnamed: 509 2014/11/3    代码.102 名称.102 MIDSZ.83
# 0        164         miss         1  '000534'   万泽股份      165
# 1        118         miss         2  '002272'   川润股份      119
# 2        116         miss         3  '002107'   沃华医药      117
# 3        107         miss         4  '000566'   海南海药      108
# 4        105         miss         5  '002401'   中海科技      106
# 5        103         miss         6  '002205'   国统股份      104
# 6        103         miss         7  '002544'   杰赛科技      104
# 7        102         miss         8  '002068'   黑猫股份      103
# 8        102         miss         9  '002338'   奥普光电      103
# 9        101         miss        10  '600674'   川投能源      102
# 10       101         miss        11  '000567'   海德股份      102
# 11       101         miss        12  '600356'   恒丰纸业      102
# 12       101         miss        13  '002171'   精诚铜业      102
# 13       101         miss        14  '002105'   信隆实业      102
# 14       100         miss        15  '002268'  卫 士 通      101
# 15        99         miss        16  '002616'   长青集团      100
# 16        99         miss        17  '002670'   华声股份      100
# 17        99         miss        18  '002318'   久立特材      100
# 18        99         miss        19  '002222'   福晶科技      100
# 19        98         miss        20  '002441'  众业达         99
# 20        98         miss        21  '002169'   智光电气       99
# 21        97         miss        22  '600038'   哈飞股份       98
# 22        96         miss        23  '002193'   山东如意       97
# 23        95         miss        24  '600976'   武汉健民       96
# 24        95         miss        25  '000099'   中信海直       96
# 25        95         miss        26  '600558'    大西洋       96
# 26        93         miss        27  '002089'  新 海 宜       94
# 27        93         miss        28  '002621'   大连三垒       94
# 28        91         miss        29  '002593'   日上集团       92
# 29        90         miss        30  '002189'   利达光电       91
# ..       ...          ...       ...       ...    ...      ...
# 504     miss         miss      miss      miss   miss     miss
# 505     miss         miss      miss      miss   miss     miss
# 506     miss         miss      miss      miss   miss     miss
# 507     miss         miss      miss      miss   miss     miss
# 508     miss         miss      miss      miss   miss     miss
# 509     miss         miss      miss      miss   miss     miss
# 510     miss         miss      miss      miss   miss     miss
# 511     miss         miss      miss      miss   miss     miss
# 512     miss         miss      miss      miss   miss     miss
# 513     miss         miss      miss      miss   miss     miss
# 514     miss         miss      miss      miss   miss     miss
# 515     miss         miss      miss      miss   miss     miss
# 516     miss         miss      miss      miss   miss     miss
# 517     miss         miss      miss      miss   miss     miss
# 518     miss         miss      miss      miss   miss     miss
# 519     miss         miss      miss      miss   miss     miss
# 520     miss         miss      miss      miss   miss     miss
# 521     miss         miss      miss      miss   miss     miss
# 522     miss         miss      miss      miss   miss     miss
# 523     miss         miss      miss      miss   miss     miss
# 524     miss         miss      miss      miss   miss     miss
# 525     miss         miss      miss      miss   miss     miss
# 526     miss         miss      miss      miss   miss     miss
# 527     miss         miss      miss      miss   miss     miss
# 528     miss         miss      miss      miss   miss     miss
# 529     miss         miss      miss      miss   miss     miss
# 530     miss         miss      miss      miss   miss     miss
# 531     miss         miss      miss      miss   miss     miss
# 532     miss         miss      miss      miss   miss     miss
# 533     miss         miss      miss      miss   miss     miss
#
# [534 rows x 514 columns]

# %%
stock_data.columns
# Out:
# Index([    u'2014/6/4',           u'代码',           u'名称',        u'MIDSZ',
#          u'Unnamed: 4',     u'2014/6/5',         u'代码.1',         u'名称.1',
#             u'MIDSZ.1',   u'Unnamed: 9',
#        ...
#        u'Unnamed: 504',   u'2014/10/31',       u'代码.101',       u'名称.101',
#            u'MIDSZ.82', u'Unnamed: 509',    u'2014/11/3',       u'代码.102',
#              u'名称.102',     u'MIDSZ.83'],
#       dtype='object', length=514)

# %%
stock_data.columns[0]
# Out:
# u'2014/6/4'

# %%
stock_data.columns[4]
# Out:
# 'Unnamed: 4'

# %%
stock_data.iloc[0][1]
# Out:
# u"'002626'"

# %%
stock_data.iloc[0][2]
# Out:
# u'\u91d1\u8fbe\u5a01  '

# %%
print stock_data.iloc[0][2]
# Out:
# 金达威

# %%
len(stock_data.columns)
# Out:
# 514

# %%
col_num = len(stock_data.columns)

# %%
#first function ,spend time lots
all_stock = pd.DataFrame()
i=0
while i <= col_num : 
    date=stock_data.columns[i]
    code=stock_data.columns[i + 1]
    code_cn=stock_data.columns[i + 2]
    print date,code,code_cn
    #
    for idx, row in stock_data.iterrows():
        # 选取需要的字段，去除其他不需要的字段
        if len(str(row[code])) > 4 :
            stock_record = pd.Series([date,row[code],row[code_cn]])
            all_stock = all_stock.append(stock_record, ignore_index=True)
    #    
    i+=5
# Out:
# 2014/6/4 代码 名称
# 2014/6/5 代码.1 名称.1
# 2014/6/6 代码.2 名称.2
# 2014/6/9 代码.3 名称.3
# 2014/6/10 代码.4 名称.4
# 2014/6/11 代码.5 名称.5
# 2014/6/12 代码.6 名称.6
# 2014/6/13 代码.7 名称.7
# 2014/6/16 代码.8 名称.8
# 2014/6/17 代码.9 名称.9
# 2014/6/18 代码.10 名称.10
# 2014/6/19 代码.11 名称.11
# 2014/6/20 代码.12 名称.12
# 2014/6/23 代码.13 名称.13
# 2014/6/24 代码.14 名称.14
# 2014/6/25 代码.15 名称.15
# 2014/6/26 代码.16 名称.16
# 2014/6/27 代码.17 名称.17
# 2014/6/30 代码.18 名称.18
# 2014/7/1 代码.19 名称.19
# 2014/7/2 代码.20 名称.20
# 2014/7/3 代码.21 名称.21
# 2014/7/4 代码.22 名称.22
# 2014/7/7 代码.23 名称.23
# 2014/7/8 代码.24 名称.24
# 2014/7/9 代码.25 名称.25
# 2014/7/10 代码.26 名称.26
# 2014/7/11 代码.27 名称.27
# 2014/7/14 代码.28 名称.28
# 2014/7/15 代码.29 名称.29
# 2014/7/16 代码.30 名称.30
# 2014/7/17 代码.31 名称.31
# 2014/7/18 代码.32 名称.32
# 2014/7/21 代码.33 名称.33
# 2014/7/22 代码.34 名称.34
# 2014/7/23 代码.35 名称.35
# 2014/7/24 代码.36 名称.36
# 2014/7/25 代码.37 名称.37
# 2014/7/28 代码.38 名称.38
# 2014/7/29 代码.39 名称.39
# 2014/7/30 代码.40 名称.40
# 2014/7/31 代码.41 名称.41
# 2014/8/1 代码.42 名称.42
# 2014/8/4 代码.43 名称.43
# 2014/8/5 代码.44 名称.44
# 2014/8/6 代码.45 名称.45
# 2014/8/7 代码.46 名称.46
# 2014/8/8 代码.47 名称.47
# 2014/8/11 代码.48 名称.48
# 2014/8/12 代码.49 名称.49
# 2014/8/13 代码.50 名称.50
# 2014/8/14 代码.51 名称.51
# 2014/8/15 代码.52 名称.52
# 2014/8/18 代码.53 名称.53
# 2014/8/19 代码.54 名称.54
# 2014/8/20 代码.55 名称.55
# 2014/8/21 代码.56 名称.56
# 2014/8/22 代码.57 名称.57
# 2014/8/25 代码.58 名称.58
# 2014/8/26 代码.59 名称.59
# 2014/8/27 代码.60 名称.60
# 2014/8/28 代码.61 名称.61
# 2014/8/29 代码.62 名称.62
# 2014/9/1 代码.63 名称.63
# 2014/9/2 代码.64 名称.64
# 2014/9/3 代码.65 名称.65
# 2014/9/4 代码.66 名称.66
# 2014/9/5 代码.67 名称.67
# 2014/9/9 代码.68 名称.68
# 2014/9/10 代码.69 名称.69
# 2014/9/11 代码.70 名称.70
# 2014/9/12 代码.71 名称.71
# 2014/9/15 代码.72 名称.72
# 2014/9/16 代码.73 名称.73
# 2014/9/17 代码.74 名称.74
# 2014/9/18 代码.75 名称.75
# 2014/9/19 代码.76 名称.76
# 2014/9/22 代码.77 名称.77
# 2014/9/23 代码.78 名称.78
# 2014/9/24 代码.79 名称.79
# 2014/9/25 代码.80 名称.80
# 2014/9/26 代码.81 名称.81
# 2014/9/29 代码.82 名称.82
# 2014/9/30 代码.83 名称.83
# 2014/10/8 代码.84 名称.84
# 2014/10/9 代码.85 名称.85
# 2014/10/10 代码.86 名称.86
# 2014/10/13 代码.87 名称.87
# 2014/10/14 代码.88 名称.88
# 2014/10/15 代码.89 名称.89
# 2014/10/16 代码.90 名称.90
# 2014/10/17 代码.91 名称.91
# 2014/10/20 代码.92 名称.92
# 2014/10/21 代码.93 名称.93
# 2014/10/22 代码.94 名称.94
# 2014/10/23 代码.95 名称.95
# 2014/10/24 代码.96 名称.96
# 2014/10/27 代码.97 名称.97
# 2014/10/28 代码.98 名称.98
# 2014/10/29 代码.99 名称.99
# 2014/10/30 代码.100 名称.100
# 2014/10/31 代码.101 名称.101
# 2014/11/3 代码.102 名称.102

# %%
#second function,spends times low
all_stock = pd.DataFrame()
for idx, row in stock_data.iterrows():
    i=0
    while i <= col_num : 
        date=stock_data.columns[i]
        code=stock_data.columns[i + 1]
        code_cn=stock_data.columns[i + 2]
        #print date,code,code_cn
        # 选取需要的字段，去除其他不需要的字段
        if len(str(row[code])) > 4 :
            stock_record = pd.Series([date,row[code],row[code_cn]])
            all_stock = all_stock.append(stock_record, ignore_index=True)
        i+=5

# %%
# 添加列名称
all_stock.columns=['date','code','code_cn']

# %%
all_stock.index.name='id'

# %%
# 非法数据
all_stock[all_stock['date']=='41775']
# Out:
# Empty DataFrame
# Columns: [date, code, code_cn]
# Index: []

# %%
need_drop_index=all_stock[all_stock['date']=='41775'].index
need_drop_index
# Out:
# Int64Index([], dtype='int64', name=u'id')

# %%
# 丢弃垃圾数据,必须用 inplace=True 才能真正改变 DataFrame 内部内容
all_stock.drop(need_drop_index,inplace=True)

# %%
# ========== 将算好的数据输出到csv文件 - 注意：这里请填写输出文件在您电脑中的路径
all_stock.to_csv(output_stock_data_cvs,encoding='gbk', index=False)
