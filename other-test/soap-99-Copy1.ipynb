# %%
# -*- coding: utf-8 -*-

import urllib2
import sys, httplib

def SendRtx(target,title,content):
    SENDTPL = \
            '''<?xml version="1.0" encoding="UTF-8"?>
    <SOAP-ENV:Envelope xmlns:SOAP-ENV="http://schemas.xmlsoap.org/soap/envelope/" xmlns:ns1="http://ws.oa.com/common/message">
        <SOAP-ENV:Body>
            <ns1:SendRTX>
                <ns1:sender>dantezhu</ns1:sender>
                <ns1:receiver>%s</ns1:receiver>
                <ns1:title>%s</ns1:title>
                <ns1:msgInfo>%s</ns1:msgInfo>
                <ns1:messageType>0</ns1:messageType>
            </ns1:SendRTX>
        </SOAP-ENV:Body>
    </SOAP-ENV:Envelope>'''

    SoapMessage = SENDTPL % (target,title,content)

    webservice = httplib.HTTP("ws.oa.com")
    webservice.putrequest("POST", "/messageservice.asmx")
    webservice.putheader("Host", "ws.oa.com")
    webservice.putheader("User-Agent", "Python Post")
    webservice.putheader("Content-type", "text/xml; charset=\"UTF-8\"")
    webservice.putheader("Content-length", "%d" % len(SoapMessage))
    webservice.putheader("SOAPAction", "\"http://ws.oa.com/common/message/SendRTX\"")
    webservice.endheaders()
    webservice.send(SoapMessage)

    # get the response

    statuscode, statusmessage, header = webservice.getreply()
    print "Response: ", statuscode, statusmessage
    print "headers: ", header
    print webservice.getfile().read()

SendRtx('dantezhu',"素材管理系统","您的单")
# Out:
# u'E:\\project\\pychram\\trade_scripts'

# %%
url = 'https://traveltest.mapple.net/hotelapi/wsdl/web.wsdl'  
client = Client(url) 
client

# %%
print client
# Out:
# Suds ( https://fedorahosted.org/suds/ )  version: 0.4 GA  build: R699-20100913
#
# Service ( MappleHotelService ) tns="https://travel.mapple.net/"
#    Prefixes (1)
#       ns0 = "https://travel.mapple.net/"
#    Ports (1):
#       (MappleHotelPort)
#          Methods (6):
#             DetailFacility(DetailFacilityRequest DetailFacilityRequest, )
#             SearchDiff(SearchDiffRequest SearchDiffRequest, )
#             SearchFacility(SearchFacilityRequest SearchFacilityRequest, )
#             SearchPlan(SearchPlanRequest SearchPlanRequest, )
#             SearchReserve(SearchReserveRequest SearchReserveRequest, )
#             UpdateReserve(UpdateReserveRequest UpdateReserveRequest, )
#          Types (144):
#             AccessInfo
#             BabysitterInfo
#             BarrierfreeSupport
#             BathEquipmentInfo
#             BathImage
#             BathRoomInfo
#             BrandInfo
#             Businesstype
#             CalcPersonPriceInfo
#             CalcPrice
#             CalcPriceInfo
#             Calendar
#             CalendarList
#             CancelPay
#             CancelPrice
#             CancelPriceRequest
#             CancelPriceResponse
#             Capacity
#             ChildExplain
#             ChildSupport
#             CommissionInfo
#             ConveniInfo
#             CookImage
#             CookInfo
#             CookOption
#             CookType
#             DetailFacility
#             DetailFacilityRequest
#             DetailFacilityResponse
#             DetailMealOptInfo
#             District
#             EndReserve
#             Etc
#             Facilitie
#             FacilityDetail
#             FacilityDetailPriceRange
#             FacilityInfo
#             FacilityRoomInfo
#             FamilyBath
#             FamilyBathInfo
#             GaikanImage
#             GetDataList
#             GetPlanPriceRequest
#             GetPlanPriceResponse
#             GetVacancyRequest
#             GetVacancyResponse
#             JimanBathInfo
#             KannaiImage
#             KannaiInfo
#             LanguageSupport
#             LargeBath
#             LargeBathInfo
#             LaundryInfo
#             MassageInfo
#             Meal
#             MealGenre
#             MealOpt
#             MealOptInfo
#             MemberInfo
#             NaturalHotSpringInfo
#             OpenBath
#             OpenBathInfo
#             ParkingInfo
#             PartnerInfo
#             PaymentInfo
#             Period
#             PersonCharge
#             PersonInfo
#             PersonPriceInfo
#             PersonsInfo
#             PetInfo
#             Place
#             PlanDetailFacilityInfo
#             PlanImage
#             PlanInfo
#             PlanPriceCalendar
#             PlanPriceCalendarList
#             PlanTerm
#             Pref
#             PriceList
#             PriceRange
#             PriceTable
#             Recreation
#             ReserveInfo
#             ReservePlanInfo
#             ReserveUserInfo
#             ResponseDetail
#             ResponseInfo
#             Restaurant
#             Room
#             RoomAmenity
#             RoomCalcPrice
#             RoomCharge
#             RoomDiv
#             RoomEquipment
#             RoomInfo
#             RoomInternetAccess
#             RoomPersonInfo
#             RoomPriceTable
#             RoomServiceInfo
#             RoomtypeInfo
#             Sauna
#             SaunaInfo
#             Schedule
#             SearchDiffFacilityInfo
#             SearchDiffPlanInfo
#             SearchDiffRequest
#             SearchDiffResponse
#             SearchDiffSearchInfo
#             SearchFacility
#             SearchFacilityRequest
#             SearchFacilityResponse
#             SearchInfo
#             SearchPlan
#             SearchPlanFacilityInfo
#             SearchPlanRequest
#             SearchPlanResponse
#             SearchReserve
#             SearchReserveFacilityInfo
#             SearchReserveRequest
#             SearchReserveResponse
#             SearchType
#             Shop
#             SpaeffectInfo
#             SpaqualityInfo
#             SpecialRates
#             Sport
#             StayInfo
#             TaxInfo
#             TemperatureInfo
#             Term
#             TermMonth
#             Time
#             TotalInfo
#             UpdateMealOptInfo
#             UpdatePersonInfo
#             UpdateReserve
#             UpdateReserveInfo
#             UpdateReserveRequest
#             UpdateReserveResponse
#             UpdateRoomInfo
#             UserInfo
#             ViewInfo
#             WifiInfo

# %%
request1 = client.factory.create('DetailFacilityRequest')
request1
# Out:
# (DetailFacilityRequest){
#    PartnerInfo =
#       (PartnerInfo){
#          p_id = None
#          p_pass = None
#       }
#    DetailFacility =
#       (DetailFacility){
#          faccode = None
#       }
#  }

# %%
partnerinfo = client.factory.create('PartnerInfo')  
partnerinfo.p_id='mapple'
partnerinfo.p_pass='mt1015'
detailfacility = client.factory.create('DetailFacility')  
detailfacility.faccode=48811

# %%
partnerinfo
# Out:
# (PartnerInfo){
#    p_id = "mapple"
#    p_pass = "mt1015"
#  }

# %%
detailfacility
# Out:
# (DetailFacility){
#    faccode = 48811
#  }

# %%
request1.PartnerInfo = partnerinfo
request1.DetailFacility = detailfacility
request1
# Out:
# (DetailFacilityRequest){
#    PartnerInfo =
#       (PartnerInfo){
#          p_id = "mapple"
#          p_pass = "mt1015"
#       }
#    DetailFacility =
#       (DetailFacility){
#          faccode = 48811
#       }
#  }

# %%
response1 = client.factory.create('DetailFacilityResponse')
response1
# Out:
# (DetailFacilityResponse){
#    ResponseInfo =
#       (ResponseInfo){
#          StatusCode = None
#          ErrorMessage = None
#       }
#    FacilityDetail =
#       (FacilityDetail){
#          FacCode = None
#          FacName = None
#          Kana = None
#          FacNameEn = None
#          Businesstype =
#             (Businesstype){
#                BusinesstypeCode = None
#                BusinesstypeName = None
#             }
#          Tel = None
#          Fax = None
#          Url = None
#          Zip = None
#          Pref =
#             (Pref){
#                PrefCode = None
#                PrefName = None
#             }
#          District =
#             (District){
#                DistrictCode = None
#                DistrictName = None
#             }
#          Address1 = None
#          Address2 = None
#          Latitude = None
#          Longitude = None
#          Headline = None
#          Guide = None
#          Attention = None
#          Image1 = None
#          MapImage = None
#          GaikanImage[] = <empty>
#          PriceRange =
#             (FacilityDetailPriceRange){
#                Minprice = None
#                Maxprice = None
#                Aveprice = None
#             }
#          CheckIn = None
#          CheckInEnd = None
#          CheckOut = None
#          MaxRoomNum = None
#          MaxVisitorNum = None
#          Recommend = None
#          Facilitie[] = <empty>
#          RangeMobile = None
#          RangePHS = None
#          WifiInfo =
#             (WifiInfo){
#                WifiCode = None
#                WifiExplain = None
#             }
#          ConveniInfo =
#             (ConveniInfo){
#                Conveni = None
#                Walk = None
#             }
#          RoomInfo =
#             (FacilityRoomInfo){
#                Room[] = <empty>
#                RoomAmenity =
#                   (RoomAmenity){
#                      Amenity[] = <empty>
#                   }
#                RoomEquipment =
#                   (RoomEquipment){
#                      Equipment[] = <empty>
#                   }
#             }
#          ParkingInfo =
#             (ParkingInfo){
#                Parking = None
#                Side = None
#                PriceDiv = None
#                Maxunit = None
#                Explain = None
#             }
#          AccessInfo =
#             (AccessInfo){
#                Transfer = None
#                MainTraffic = None
#                TrainGuide = None
#                CarGuide = None
#                AirportGuide = None
#             }
#          KannaiInfo =
#             (KannaiInfo){
#                Recreation =
#                   (Recreation){
#                      RecreationName[] = <empty>
#                   }
#                Sport =
#                   (Sport){
#                      SportName[] = <empty>
#                   }
#                Place =
#                   (Place){
#                      PlaceName[] = <empty>
#                   }
#                Restaurant =
#                   (Restaurant){
#                      RestaurantName[] = <empty>
#                   }
#                Shop =
#                   (Shop){
#                      ShopName[] = <empty>
#                   }
#                Etc =
#                   (Etc){
#                      EtcName[] = <empty>
#                   }
#                KannaiImage =
#                   (KannaiImage){
#                      Image = None
#                      ImageExplain = None
#                   }
#             }
#          CookInfo =
#             (CookInfo){
#                CookType =
#                   (CookType){
#                      CookName[] = <empty>
#                   }
#                CookOption =
#                   (CookOption){
#                      CookExplain[] = <empty>
#                   }
#                CookImage[] = <empty>
#             }
#          ChildSupport =
#             (ChildSupport){
#                Equipment[] = <empty>
#             }
#          BarrierfreeSupport =
#             (BarrierfreeSupport){
#                LimbsDisable[] = <empty>
#                VisualDisable[] = <empty>
#                HearingDisable[] = <empty>
#                AgeDisable[] = <empty>
#                Explain = None
#             }
#          LanguageSupport =
#             (LanguageSupport){
#                Support = None
#                Chinese = None
#                English = None
#                French = None
#                German = None
#                Italian = None
#                Korean = None
#                Spanish = None
#                OtherLanguage[] = <empty>
#             }
#          BathRoomInfo =
#             (BathRoomInfo){
#                LargeBathInfo =
#                   (LargeBathInfo){
#                      LargeBath[] = <empty>
#                   }
#                OpenBathInfo =
#                   (OpenBathInfo){
#                      OpenBath[] = <empty>
#                   }
#                SaunaInfo =
#                   (SaunaInfo){
#                      Sauna[] = <empty>
#                      SaunaPrice = None
#                   }
#                FamilyBathInfo =
#                   (FamilyBathInfo){
#                      FamilyBath[] = <empty>
#                      Reserve = None
#                   }
#                TemperatureInfo =
#                   (TemperatureInfo){
#                      Min = None
#                      Max = None
#                   }
#                Spatype = None
#                KurhausNum = None
#                JacuzziNum = None
#                WaterNum = None
#                NaturalHotSpringInfo =
#                   (NaturalHotSpringInfo){
#                      Circulation = None
#                      AddWater = None
#                      Warming = None
#                      Explain = None
#                   }
#                BathEquipmentInfo =
#                   (BathEquipmentInfo){
#                      BathEquipmentName[] = <empty>
#                   }
#                SpaqualityInfo =
#                   (SpaqualityInfo){
#                      Spaquality[] = <empty>
#                   }
#                SpaeffectInfo =
#                   (SpaeffectInfo){
#                      Spaeffect[] = <empty>
#                   }
#                BathImage[] = <empty>
#                JimanBathInfo[] = <empty>
#             }
#          PetInfo =
#             (PetInfo){
#                Pet = None
#                NearStayPlace = None
#                Move = None
#                MoveMinute = None
#                Bring = None
#                Explain = None
#             }
#          BabysitterInfo =
#             (BabysitterInfo){
#                Babysitter = None
#                Reserve = None
#                Keep =
#                   (Time){
#                      StartTime = None
#                      EndTime = None
#                   }
#                PriceType = None
#                Explain = None
#             }
#          LaundryInfo =
#             (LaundryInfo){
#                Laundry = None
#                Accept =
#                   (Time){
#                      StartTime = None
#                      EndTime = None
#                   }
#                Finish =
#                   (Time){
#                      StartTime = None
#                      EndTime = None
#                   }
#                Explain = None
#             }
#          RoomServiceInfo =
#             (RoomServiceInfo){
#                RoomService = None
#                Service1 =
#                   (Time){
#                      StartTime = None
#                      EndTime = None
#                   }
#                Service2 =
#                   (Time){
#                      StartTime = None
#                      EndTime = None
#                   }
#                Price = None
#                Tariff = None
#                Explain = None
#             }
#          MassageInfo =
#             (MassageInfo){
#                Massage = None
#                Accept =
#                   (Time){
#                      StartTime = None
#                      EndTime = None
#                   }
#                Hour = None
#                Price = None
#                Explain = None
#             }
#       }
#  }

# %%
response1 = client.service.DetailFacility(request1)
# Out:
# ERROR:suds.umx.typed:Schema:0x6535530
# (raw)
#    <xsd:schema>
#       <xsd:import schemaLocation="web.xsd" namespace="https://travel.mapple.net/"/>
#    </xsd:schema>
# (model)
# ---------------------------------------------------------------------------
# TypeNotFound                              Traceback (most recent call last)
# <ipython-input-14-2c52ad70c345> in <module>()
# ----> 1 response1 = client.service.DetailFacility(request1)
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\client.pyc in __call__(self, *args, **kwargs)
#     540                 return (500, e)
#     541         else:
# --> 542             return client.invoke(args, kwargs)
#     543
#     544     def faults(self):
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\client.pyc in invoke(self, args, kwargs)
#     600                 timer)
#     601         timer.start()
# --> 602         result = self.send(soapenv)
#     603         timer.stop()
#     604         metrics.log.debug(
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\client.pyc in send(self, soapenv)
#     641                 result = reply.message
#     642             else:
# --> 643                 result = self.succeeded(binding, reply.message)
#     644         except TransportError, e:
#     645             if e.httpcode in (202,204):
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\client.pyc in succeeded(self, binding, reply)
#     676         plugins = PluginContainer(self.options.plugins)
#     677         if len(reply) > 0:
# --> 678             reply, result = binding.get_reply(self.method, reply)
#     679             self.last_received(reply)
#     680         else:
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\bindings\binding.pyc in get_reply(self, method, reply)
#     163                 unmarshaller = self.unmarshaller()
#     164                 resolved = rtypes[0].resolve(nobuiltin=True)
# --> 165                 result = unmarshaller.process(nodes[0], resolved)
#     166                 return (replyroot, result)
#     167         return (replyroot, None)
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\typed.pyc in process(self, node, type)
#      64         content = Content(node)
#      65         content.type = type
# ---> 66         return Core.process(self, content)
#      67
#      68     def reset(self):
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in process(self, content)
#      46         """
#      47         self.reset()
# ---> 48         return self.append(content)
#      49
#      50     def append(self, content):
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in append(self, content)
#      61         self.start(content)
#      62         self.append_attributes(content)
# ---> 63         self.append_children(content)
#      64         self.append_text(content)
#      65         self.end(content)
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in append_children(self, content)
#     138         for child in content.node:
#     139             cont = Content(child)
# --> 140             cval = self.append(cont)
#     141             key = reserved.get(child.name, child.name)
#     142             if key in content.data:
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in append(self, content)
#      61         self.start(content)
#      62         self.append_attributes(content)
# ---> 63         self.append_children(content)
#      64         self.append_text(content)
#      65         self.end(content)
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in append_children(self, content)
#     138         for child in content.node:
#     139             cont = Content(child)
# --> 140             cval = self.append(cont)
#     141             key = reserved.get(child.name, child.name)
#     142             if key in content.data:
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in append(self, content)
#      61         self.start(content)
#      62         self.append_attributes(content)
# ---> 63         self.append_children(content)
#      64         self.append_text(content)
#      65         self.end(content)
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in append_children(self, content)
#     138         for child in content.node:
#     139             cont = Content(child)
# --> 140             cval = self.append(cont)
#     141             key = reserved.get(child.name, child.name)
#     142             if key in content.data:
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\core.pyc in append(self, content)
#      59         @see: L{process()}
#      60         """
# ---> 61         self.start(content)
#      62         self.append_attributes(content)
#      63         self.append_children(content)
#
# c:\Python\Python27\lib\site-packages\suds-0.4-py2.7.egg\suds\umx\typed.pyc in start(self, content)
#      78             if found is None:
#      79                 log.error(self.resolver.schema)
# ---> 80                 raise TypeNotFound(content.node.qname())
#      81             content.type = found
#      82         else:
#
# TypeNotFound: Type not found: 'Explain'
